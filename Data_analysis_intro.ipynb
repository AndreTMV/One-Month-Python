# %% [markdown]
# # Import pandas

# %%
import pandas as pd

# %% [markdown]
# # Importing Data

# %%
name = ['Id','Name','Year','Rating','Votes','Length','Genre']
data = pd.read_csv('imdb_top_10000.txt',sep='\t',names=name,index_col=0) # reading a file -> sep -> default(commas(comma spe value(csv)))
data.head() # first five rows
data.tail(3) # last fice rows -> enter how man rows want to be displayed
data.info() # Info column
data.describe()
data.to_csv('test.txt',header=True,index=True,sep='\t') # Exporting data
data.sort_values(by='Rating') # sorting data
data.sort_values(by='Rating',ascending=False) # from greates to lowest
data['Name'] # set of data
data[['Name','Year']]
data['Rating'].mean() # promedio
data['Rating'].max() # max value
data['Rating'].min() # min value
data['Genre'].unique() # Searching the no repeted keys
data['Rating'].value_counts() # Counting how many values are repeated in a key
data['Rating'].value_counts().sort_index() # Counting how many values are repeated in a key in a sorted way
data['Rating'].value_counts().sort_index(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10000 non-null  object
#  1   Year    10000 non-null  int64
#  2   Rating  10000 non-null  float64
#  3   Votes   10000 non-null  int64
#  4   Length  10000 non-null  object
#  5   Genre   9999 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB
# 9.2     2
# 9.0     4
# 8.9     5
# 8.8     9
# 8.7    13
#        ..
# 1.9     9
# 1.8    12
# 1.7    12
# 1.6     6
# 1.5     7
# Name: Rating, Length: 77, dtype: int64

# %% [markdown]
# # Exploring our Data

# %% [markdown]
# # Creating Data Frames from scratch

# %%
sample_data ={
    'tv':[123,456,234],
    'radio':[68,69,70],
    'news':[12,31,5432],
    'sales':[13,121,521]
}
data2 = pd.DataFrame(sample_data)
data2.head()
# del data2 # deletes the data frame
# Out:
#     tv  radio  news  sales
# 0  123     68    12     13
# 1  456     69    31    121
# 2  234     70  5432    521

# %% [markdown]
# # Plotting

# %%
# %matplotlib inline

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Id'>

# %%
data.plot(kind='scatter',x='Rating',y='Votes',alpha=0.3)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Votes'>

# %%
data['Rating'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import seaborn as sns

# %%
sns.lmplot(x='Rating',y='Votes',data=data)

# %%
sns.pairplot(data)

# %%
import statsmodels.api as sm
import pandas as pd
import seaborn as sns

# %%
name = ['Id','Name','Year','Rating','Votes','Length','Genre']
data = pd.read_csv('imdb_top_10000.txt',sep='\t',names=name,index_col=0)

# %%
results = sm.OLS(data['Votes'], data['Rating']).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Votes   R-squared (uncentered):                   0.221
# Model:                            OLS   Adj. R-squared (uncentered):              0.220
# Method:                 Least Squares   F-statistic:                              2829.
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):                        0.00
# Time:                        16:01:29   Log-Likelihood:                     -1.1849e+05
# No. Observations:               10000   AIC:                                  2.370e+05
# Df Residuals:                    9999   BIC:                                  2.370e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Advanced Data selection

# %%
data[data['Year'] > 2004].sort_values(by='Rating',ascending = False)
# Out:
#                                              Name  Year  Rating   Votes  \
# Id
# tt1375666                        Inception (2010)  2010     8.9  385149
# tt0468569                  The Dark Knight (2008)  2008     8.9  555122
# tt0476735             My Father and My Son (2005)  2005     8.7   14080
# tt1832382                     A Separation (2011)  2011     8.6   11954
# tt0435761                      Toy Story 3 (2010)  2010     8.6  144200
# ...                                           ...   ...     ...     ...
# tt0830861                 The Little Fox 2 (2008)  2008     1.7    3410
# tt0469849                    Too Beautiful (2005)  2005     1.7    2055
# tt0473310  Ram Gopal Varma's Indian Flames (2007)  2007     1.6    2511
# tt0417056                     Pledge This! (2006)  2006     1.6    8362
# tt1309000                       Dream Well (2009)  2009     1.5    2848
#
#               Length                                      Genre
# Id
# ...

# %%
data['Year'] > 1995
# Out:
# Id
# tt0111161    False
# tt0110912    False
# tt0137523     True
# tt0133093     True
# tt1375666     True
#              ...
# tt0807721     True
# tt0339642     True
# tt0060880    False
# tt0152836     True
# tt0279977     True
# Name: Year, Length: 10000, dtype: bool

# %%
data[data['Year'] == 2004]
# Out:
#                                                    Name  Year  Rating   Votes  \
# Id
# tt0338013  Eternal Sunshine of the Spotless Mind (2004)  2004     8.5  260298
# tt0317705                        The Incredibles (2004)  2004     8.1  191778
# tt0378194                      Kill Bill: Vol. 2 (2004)  2004     8.0  216272
# tt0375679                                  Crash (2004)  2004     8.0  194749
# tt0405159                    Million Dollar Baby (2004)  2004     8.2  171194
# ...                                                 ...   ...     ...     ...
# tt0378417              Night of the Living Dorks (2004)  2004     5.8    1391
# tt0377057            Elvis Has Left the Building (2004)  2004     5.2    1368
# tt0388364                               Red Dust (2004)  2004     6.8    1360
# tt0368259            Sex Lives of the Potato Men (2004)  2004     4.3    1362
# tt0339727                              Stateside (2004)  2004     5.8    1358
#
# ...

# %%
data[(data['Year'] >= 2000) & (data['Year'] <= 2004)].sort_values(by='Rating', ascending = False).head(10)
# Out:
#                                                         Name  Year  Rating  \
# Id
# tt0317248                                 City of God (2002)  2002     8.8
# tt0167260  The Lord of the Rings: The Return of the King ...  2003     8.8
# tt0120737  The Lord of the Rings: The Fellowship of the R...  2001     8.8
# tt0209144                                     Memento (2000)  2000     8.7
# tt0167261       The Lord of the Rings: The Two Towers (2002)  2002     8.7
# tt0245429                               Spirited Away (2001)  2001     8.6
# tt0180093                         Requiem for a Dream (2000)  2000     8.5
# tt0253474                                 The Pianist (2002)  2002     8.5
# tt0211915                                   Am\xe9lie (2001)  2001     8.5
# tt0338013       Eternal Sunshine of the Spotless Mind (2004)  2004     8.5
#
#             Votes     Length                               Genre
# Id
# tt0317248  199917  130 mins.                         Crime|Drama
# ...

# %% [markdown]
# # Grouping

# %%
data.groupby(data['Year'])['Rating'].mean()
# Out:
# Year
# 1950    7.545161
# 1951    7.478125
# 1952    7.475676
# 1953    7.106383
# 1954    7.371795
#           ...
# 2007    6.303831
# 2008    6.275260
# 2009    6.287290
# 2010    6.340635
# 2011    6.357143
# Name: Rating, Length: 62, dtype: float64

# %%
data.groupby(data['Year'])['Rating'].max()
# Out:
# Year
# 1950    8.7
# 1951    8.3
# 1952    8.4
# 1953    8.3
# 1954    8.8
#        ...
# 2007    8.3
# 2008    8.9
# 2009    8.4
# 2010    8.9
# 2011    8.6
# Name: Rating, Length: 62, dtype: float64

# %%
data.groupby(data['Year'])['Rating'].min()
# Out:
# Year
# 1950    6.3
# 1951    6.2
# 1952    6.3
# 1953    2.9
# 1954    6.1
#        ...
# 2007    1.6
# 2008    1.7
# 2009    1.5
# 2010    2.2
# 2011    2.1
# Name: Rating, Length: 62, dtype: float64

# %%
data.sort_values(by='Rating', ascending = False).head() # 1994 & 1972
# Out:
#                                             Name  Year  Rating   Votes  \
# Id
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0252487                Outrageous Class (1975)  1975     9.0    9823
#
#               Length           Genre
# Id
# tt0111161  142 mins.     Crime|Drama
# tt0068646  175 mins.     Crime|Drama
# tt0060196  161 mins.         Western
# tt0110912  154 mins.  Crime|Thriller
# tt0252487   87 mins.    Comedy|Drama

# %%
data[data['Year'] == 1996].sort_values(by='Rating', ascending = False).head() # Fargo
# Out:
#                             Name  Year  Rating   Votes     Length  \
# Id
# tt0116282           Fargo (1996)  1996     8.3  187498   98 mins.
# tt0116231      The Bandit (1996)  1996     8.3   13288  121 mins.
# tt0117951   Trainspotting (1996)  1996     8.2  175993   94 mins.
# tt0117666     Sling Blade (1996)  1996     8.0   44316  135 mins.
# tt0117589  Secrets & Lies (1996)  1996     8.0   15435  142 mins.
#
#                                          Genre
# Id
# tt0116282                 Crime|Drama|Thriller
# tt0116231  Action|Crime|Drama|Romance|Thriller
# tt0117951                          Crime|Drama
# tt0117666                                Drama
# tt0117589                         Comedy|Drama

# %%
data.sort_values(by='Votes', ascending = False).head(5) # Five most voted movies -> my solution
# Out:
#                                       Name  Year  Rating   Votes     Length  \
# Id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0468569           The Dark Knight (2008)  2008     8.9  555122  152 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
#
#                                  Genre
# Id
# tt0111161                  Crime|Drama
# tt0468569  Action|Crime|Drama|Thriller
# tt0110912               Crime|Thriller
# tt0068646                  Crime|Drama
# tt0137523       Drama|Mystery|Thriller

# %%
data[data['Rating'] == data['Rating'].max()] # One month solution
# Out:
#                                       Name  Year  Rating   Votes     Length  \
# Id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
#
#                  Genre
# Id
# tt0111161  Crime|Drama
# tt0068646  Crime|Drama

# %%
data.groupby((data['Year'] >= 1960) & (data['Year'] <= 1969))['Rating'].mean()
# Out:
# Year
# False    6.345495
# True     7.062367
# Name: Rating, dtype: float64

# %%
#data.groupby(data['Rating'])[(data['Year'] >= 1960) & (data['Year'] <= 1969)].mean()

# %%
data.groupby((data['Year'] >= 1960) & (data['Year'] <= 1969))['Rating'].max()
# Out:
# Year
# False    9.2
# True     9.0
# Name: Rating, dtype: float64

# %%
y1960 = data[(data['Year'] >= 1960) & (data['Year'] <= 1969)]
y1960.groupby(y1960['Year'])['Rating'].mean().sort_values(ascending = False).head(1) # 1962 most high average movie -> my solution
# Out:
# Year
# 1962    7.349057
# Name: Rating, dtype: float64

# %%
data[(data['Year'] >= 1960) & (data['Year'] <= 1969)].groupby(data['Year'])['Rating'].mean().sort_values(ascending=False).head(1) # One month solution
# Out:
# Year
# 1962    7.349057
# Name: Rating, dtype: float64

# %% [markdown]
# # Cleaning Data

# %%
data['Formated name'] = data['Name'].str[:-7]
data.head()
# Out:
#                                       Name  Year  Rating   Votes     Length  \
# Id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                       Genre             Formated name  \
# Id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#                      Formatted name
# Id
# ...

# %%
data['Formatted name'] = data['Name'].str.split(' \(').str[0]
data['Formatted name'] = data['Name'].str.split(' \(').str.get(0)

# %%
data.head()
# Out:
#                                       Name  Year  Rating   Votes     Length  \
# Id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                       Genre             Formated name  \
# Id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#                      Formatted name
# Id
# ...

# %%
#data['Length'].str[:-6]
#data['Length'].str.split().str.get(0)
#data['Length'].str.replace(' min ', ' ' ).astype('int')
data['Formatted Length'] = data['Length'].str.split().str.get(0).astype('int')
data.head()
# Out:
#                                       Name  Year  Rating   Votes     Length  \
# Id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                       Genre             Formated name  \
# Id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#                      Formatted name  Formatted Length
# Id
# ...

# %%
sns.pairplot(data)

# %%
data[data['Formatted Length'] == 0]
# Out:
#                                                  Name  Year  Rating   Votes  \
# Id
# tt0457430                      Pan's Labyrinth (2006)  2006     8.4  186080
# tt0081505                          The Shining (1980)  1980     8.5  212988
# tt1077258                        Planet Terror (2007)  2007     7.5   74950
# tt0075860   Close Encounters of the Third Kind (1977)  1977     7.8   65768
# tt0054331                            Spartacus (1960)  1960     8.0   55504
# ...                                               ...   ...     ...     ...
# tt1042499                     Filth and Wisdom (2008)  2008     5.1    1367
# tt0094642                      American Gothic (1988)  1988     5.1    1359
# tt1926313                   Pyaar Ka Punchnama (2011)  2011     8.0    1359
# tt0878674                               Garage (2007)  2007     6.9    1356
# tt0197094  What Becomes of the Broken Hearted? (1999)  1999     6.3    1365
#
# ...
